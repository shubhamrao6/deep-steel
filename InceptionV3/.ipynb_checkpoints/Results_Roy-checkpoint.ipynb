# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import cv2

# %% [markdown]
# # Single Learning Rate

# %%
# Validation loss
val_loss = np.load('./data/Roy/InceptionNetV3_loss.npy')

plt.figure(figsize=(10,5))
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.plot(val_loss[4:],color='red')

# %%
# Validation loss
val_acc = np.load('./data/Roy/InceptionNetV3_acc.npy')

plt.figure(figsize=(10,5))
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.plot(val_acc,color='red')

# %%
# Max Accuracy reached
print(val_acc.max())
np.argmax(val_acc)
# Out:
# 0.99666667
# 74

# %% [markdown]
# # Learning Rate Decay

# %%
# Validation loss
val_loss2 = np.load('./data/Roy/InceptionNetV3_loss_LRD.npy')

plt.figure(figsize=(10,5))
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.plot(val_loss2, color='green')

# %%
# Validation loss
val_acc2 = np.load('./data/Roy/InceptionNetV3_acc_LRD.npy')

plt.figure(figsize=(10,5))
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.plot(val_acc2,color='green')

# %%
# Max Accuracy reached
print(val_acc2.max())
np.argmax(val_acc2)
# Out:
# 0.99666667
# 87

# %% [markdown]
# # Step Reduced Learning Rate

# %%
# Validation loss
val_loss3 = np.load('./data/Roy/InceptionNetV3_loss_Srlr.npy')

plt.figure(figsize=(10,5))
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.plot(val_loss3[1:])

# %%
# Validation loss
val_acc3 = np.load('./data/Roy/InceptionNetV3_acc_Srlr.npy')

plt.figure(figsize=(10,5))
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.plot(val_acc3)

# %%
print(val_acc3.max())
np.argmax(val_acc3)
# Out:
# 0.99333334
# 77

# %% [markdown]
# # Comparing all the methods

# %%
plt.figure(figsize=(15,7.5))
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.plot(val_acc3[:100], label='SrLr')
plt.plot(val_acc2, color='green', label='LrD')
plt.plot(val_acc, color='red', label='SLr')
plt.legend(loc="lower right")

# %%
plt.figure(figsize=(15,7.5))
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.plot(val_loss3[4:], label='SrLr')
plt.plot(val_loss2, color='green', label='LrD')
plt.plot(val_loss[4:], color='red', label='SLr')
plt.legend(loc="upper right")
