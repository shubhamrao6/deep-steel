# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# %% [markdown]
# # Single Learning Rate

# %%
# Validation loss
val_loss = np.load('./data/InceptionV3_loss0-80.npy')

plt.figure(figsize=(10,5))
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.plot(val_loss,color='red')

# %%
# Validation loss
val_acc = np.load('./data/InceptionV3_acc0-80.npy')

plt.figure(figsize=(10,5))
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.plot(val_acc,color='red')

# %%
# Max Accuracy reached
np.argmax(val_acc)
# Out:
# 93

# %% [markdown]
# # Step Reduced Learning Rate

# %%
# Validation loss
val_loss2 = np.load('./data/inceptionv3_2_loss0-80.npy')

plt.figure(figsize=(10,5))
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.plot(val_loss2)

# %%
# Validation loss
val_acc2 = np.load('./data/inceptionv3__acc0-80.npy')

plt.figure(figsize=(10,5))
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.plot(val_acc2)

# %%
# Max Accuracy reached
np.argmax(val_acc2)
# Out:
# 18

# %% [markdown]
# # Comparing both the method

# %%
plt.figure(figsize=(15,7))
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.plot(val_acc2, label='SrLr')
plt.plot(val_acc, color='red', label='SLr')
plt.legend(loc="lower right")

# %%
plt.figure(figsize=(15,7))
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.plot(val_loss2, label='SrLr')
plt.plot(val_loss, color='red', label='SLr')
plt.legend(loc="upper right")
